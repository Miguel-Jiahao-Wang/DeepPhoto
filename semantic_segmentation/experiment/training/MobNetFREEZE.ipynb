# %% [markdown]
# # Training using freezed MobileNet as backbone

# %% [markdown]
# ## Setup and imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/DeepLearningX/gitclone/light-weight-refinenet/src
# Out:
# /content/drive/My Drive/DeepLearningX/gitclone/light-weight-refinenet/src

# %%
# general libs
import argparse
import logging
import os
import random
import re
import sys
import time

# misc
import cv2
import numpy as np

# pytorch libs
import torch
import torch.nn as nn
from sklearn.metrics import confusion_matrix

# custom libs
from util import *

# %% [markdown]
# ## Methods for training

# %%
# define methods for training
sys.path.append("..")

from models.mobilenet import mbv2
from torchvision import transforms
from torch.utils.data import DataLoader, random_split
# Custom libraries
from datasets import NYUDataset as Dataset
from datasets import Pad, RandomCrop, RandomMirror, ResizeShorterScale, ToTensor, Normalise

def create_segmenter(
    net, pretrained, num_classes
    ):
    """Create Encoder; for now only ResNet [50,101,152]"""
    from models.resnet import rf_lw50, rf_lw101, rf_lw152
    if str(net) == '50':
        return rf_lw50(num_classes, imagenet=pretrained)
    elif str(net) == '101':
        return rf_lw101(num_classes, imagenet=pretrained)
    elif str(net) == '152':
        return rf_lw152(num_classes, imagenet=pretrained)
    elif str(net) == 'Mob':
        return mbv2(num_classes, pretrained=pretrained)
    else:
        raise ValueError("{} is not supported".format(str(net)))

def create_loaders(
    train_dir, val_dir, train_list, val_list,
    shorter_side, crop_size, low_scale, high_scale,
    normalise_params, batch_size, num_workers, ignore_label
    ):
    """
    Args:
      train_dir (str) : path to the root directory of the training set.
      val_dir (str) : path to the root directory of the validation set.
      train_list (str) : path to the training list.
      val_list (str) : path to the validation list.
      shorter_side (int) : parameter of the shorter_side resize transformation.
      crop_size (int) : square crop to apply during the training.
      low_scale (float) : lowest scale ratio for augmentations.
      high_scale (float) : highest scale ratio for augmentations.
      normalise_params (list / tuple) : img_scale, img_mean, img_std.
      batch_size (int) : training batch size.
      num_workers (int) : number of workers to parallelise data loading operations.
      ignore_label (int) : label to pad segmentation masks with

    Returns:
      train_loader, val loader

    """

    ## Transformations during training ##
    composed_trn = transforms.Compose([ResizeShorterScale(shorter_side, low_scale, high_scale),
                                    Pad(crop_size, [123.675, 116.28 , 103.53], ignore_label),
                                    RandomMirror(),
                                    RandomCrop(crop_size),
                                    Normalise(*normalise_params),
                                    ToTensor()])
    composed_val = transforms.Compose([Normalise(*normalise_params),
                                    ToTensor()])
    ## Training and validation sets ##
    trainset = Dataset(data_file=train_list,
                       data_dir=train_dir,
                       transform_trn=composed_trn,
                       transform_val=composed_val)

    valset = Dataset(data_file=val_list,
                         data_dir=val_dir,
                         transform_trn=None,
                         transform_val=composed_val)
    logger.info(" Created train set = {} examples, val set = {} examples"
                .format(len(trainset), len(valset)))
    ## Training and validation loaders ##
    train_loader = DataLoader(trainset,
                              batch_size=batch_size,
                              shuffle=True,
                              num_workers=num_workers,
                              pin_memory=True,
                              drop_last=True)
    val_loader = DataLoader(valset,
                            batch_size=1,
                            shuffle=False,
                            num_workers=num_workers,
                            pin_memory=True)
    return train_loader, val_loader

def create_optimisers(
    lr_enc, lr_dec,
    mom_enc, mom_dec,
    wd_enc, wd_dec,
    param_enc, param_dec,
    optim_dec
    ):
    """Create optimisers for encoder, decoder and controller"""
    optim_enc = torch.optim.SGD(param_enc, lr=lr_enc, momentum=mom_enc,
                                weight_decay=wd_enc)
    if optim_dec == 'sgd':
        optim_dec = torch.optim.SGD(param_dec, lr=lr_dec,
                                    momentum=mom_dec, weight_decay=wd_dec)
    elif optim_dec == 'adam':
        optim_dec = torch.optim.Adam(param_dec, lr=lr_dec, weight_decay=wd_dec, eps=1e-3)
    return optim_enc, optim_dec

def load_ckpt(
    ckpt_path, ckpt_dict
    ):
    best_val = epoch_start = 0
    if os.path.exists(CKPT_PATH):
        ckpt = torch.load(ckpt_path)
        for (k, v) in ckpt_dict.items():
            if k in ckpt:
                v.load_state_dict(ckpt[k])
        best_val = ckpt.get('best_val', 0)
        epoch_start = ckpt.get('epoch_start', 0)
        logger.info(" Found checkpoint at {} with best_val {:.4f} at epoch {}".
            format(
                ckpt_path, best_val, epoch_start
            ))
    return best_val, epoch_start

def train_segmenter(
    segmenter, train_loader, optim_enc, optim_dec,
    epoch, segm_crit, freeze_bn
    ):
    """Training segmenter

    Args:
      segmenter (nn.Module) : segmentation network
      train_loader (DataLoader) : training data iterator
      optim_enc (optim) : optimiser for encoder
      optim_dec (optim) : optimiser for decoder
      epoch (int) : current epoch
      segm_crit (nn.Loss) : segmentation criterion
      freeze_bn (bool) : whether to keep BN params intact

    """
    train_loader.dataset.set_stage('train')
    segmenter.train()
    if freeze_bn:
        for m in segmenter.modules():
            if isinstance(m, nn.BatchNorm2d):
                m.eval()
    batch_time = AverageMeter()
    losses = AverageMeter()
    for i, sample in enumerate(train_loader):
        start = time.time()
        input = sample['image'].cuda()
        target = sample['mask'].cuda()
        input_var = torch.autograd.Variable(input).float()
        target_var = torch.autograd.Variable(target).long()
        # Compute output
        output = segmenter(input_var)
        output = nn.functional.interpolate(output, size=target_var.size()[1:], mode='bilinear', align_corners=False)
        soft_output = nn.LogSoftmax()(output)
        # Compute loss and backpropagate
        loss = segm_crit(soft_output, target_var)
        optim_enc.zero_grad()
        optim_dec.zero_grad()
        loss.backward()
        optim_enc.step()
        optim_dec.step()
        losses.update(loss.item())
        batch_time.update(time.time() - start)
        if i % PRINT_EVERY == 0:
            logger.info(' Train epoch: {} [{}/{}]\t'
                        'Avg. Loss: {:.3f}\t'
                        'Avg. Time: {:.3f}'.format(
                            epoch, i, len(train_loader),
                            losses.avg, batch_time.avg
                        ))
def compute_iu(cm):
    """Compute IU from confusion matrix.

    Args:
      cm (Tensor) : square confusion matrix.

    Returns:
      IU vector (Tensor).

    """
    pi = 0
    gi = 0
    ii = 0
    denom = 0
    n_classes = cm.shape[0]
    IU = np.ones(n_classes)
    
    for i in range(n_classes):
        pi = sum(cm[:, i])
        gi = sum(cm[i, :])
        ii = cm[i, i]
        denom = pi + gi - ii
        if denom > 0:
            IU[i] = ii / denom
    return IU

def validate(
    segmenter, val_loader, epoch, path, num_classes=-1
    ):
    """Validate segmenter

    Args:
      segmenter (nn.Module) : segmentation network
      val_loader (DataLoader) : training data iterator
      epoch (int) : current epoch
      num_classes (int) : number of classes to consider

    Returns:
      Mean IoU (float)
    """
    val_loader.dataset.set_stage('val')
    segmenter.eval()
    cm = np.zeros((num_classes, num_classes), dtype=int)
    with torch.no_grad():
        for i, sample in enumerate(val_loader):
            start = time.time()
            input = sample['image']
            target = sample['mask']
            input_var = torch.autograd.Variable(input).float().cuda()
            # Compute output
            output = segmenter(input_var)
            output = cv2.resize(output[0, :num_classes].data.cpu().numpy().transpose(1, 2, 0),
                                target.size()[1:][::-1],
                                interpolation=cv2.INTER_CUBIC).argmax(axis=2).astype(np.uint8)
            # Compute IoU
            gt = target[0].data.cpu().numpy().astype(np.uint8)
            gt_idx = gt < num_classes # Ignore every class index larger than the number of classes
            cm += confusion_matrix(output[gt_idx], gt[gt_idx])

            # if i % PRINT_EVERY == 0:
            #     logger.info(' Val epoch: {} [{}/{}]\t'
            #                 'Mean IoU: {:.3f}'.format(
            #                     epoch, i, len(val_loader),
            #                     compute_iu(cm).mean()
            #                 ))

    ious = compute_iu(cm)
    logger.info(" IoUs: {}".format(ious))
    miou = np.mean(ious)
    
    with open(path, 'a') as f:
      f.write("{}\n".format(miou))

    logger.info(' Val epoch: {}\tMean IoU: {:.3f}'.format(
                                epoch, miou))
    return miou

def main(modelPath, metricPath):
    logging.basicConfig(level=logging.INFO)
    global logger #, args
    # args = get_arguments()
    logger = logging.getLogger(__name__)
    
    ## Add args ##
    NUM_STAGES = len(NUM_CLASSES)

    ## Set random seeds ##
    torch.backends.cudnn.deterministic = True
    torch.manual_seed(RANDOM_SEED)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    random.seed(RANDOM_SEED)
    
    ## Generate Segmenter ##
    segmenter = nn.DataParallel(
        create_segmenter(ENC, ENC_PRETRAINED, NUM_CLASSES[0])
        ).cuda()

    # segmenter = create_segmenter(ENC, ENC_PRETRAINED, NUM_CLASSES[0]).cuda()
    logger.info(" Loaded Segmenter {}, ImageNet-Pre-Trained={}, #PARAMS={:3.2f}M"
                .format(ENC, ENC_PRETRAINED, compute_params(segmenter) / 1e6))
    
    ## Restore if any ## (at checkpoint)
    best_val, epoch_start = load_ckpt(CKPT_PATH, {'segmenter' : segmenter})
    
    ## Criterion ##
    segm_crit = nn.NLLLoss2d(ignore_index=IGNORE_LABEL).cuda()

    # ## Saver ##
    # saver = Saver(args=vars(args),
    #               ckpt_dir=SNAPSHOT_DIR,
    #               best_val=best_val,
    #               condition=lambda x, y: x > y)  # keep checkpoint with the best validation score

    logger.info(" Training Process Starts")
    for task_idx in range(NUM_STAGES):
        start = time.time()
        torch.cuda.empty_cache()
        ## Create dataloaders ##
        train_loader, val_loader = create_loaders(TRAIN_DIR,
                                                  VAL_DIR,
                                                  TRAIN_LIST[task_idx],
                                                  VAL_LIST[task_idx],
                                                  SHORTER_SIDE[task_idx],
                                                  CROP_SIZE[task_idx],
                                                  LOW_SCALE[task_idx],
                                                  HIGH_SCALE[task_idx],
                                                  NORMALISE_PARAMS,
                                                  BATCH_SIZE[task_idx],
                                                  NUM_WORKERS,
                                                  IGNORE_LABEL)
        if EVALUATE:
            return validate(segmenter, val_loader, 0, metricPath + "miousFreeze.txt", num_classes=2)

        logger.info(" Training Stage {}".format(str(task_idx)))
        ## Optimisers ##
        enc_params = []
        dec_params = []
        for k,v in segmenter.named_parameters():
            if bool(re.match(".*layer.*", k)):
                enc_params.append(v)
                #logger.info(" Enc. parameter: {}".format(k))
            else:
                dec_params.append(v)
                #logger.info(" Dec. parameter: {}".format(k))
        optim_enc, optim_dec = create_optimisers(LR_ENC[task_idx], LR_DEC[task_idx],
                                                 MOM_ENC[task_idx], MOM_DEC[task_idx],
                                                 WD_ENC[task_idx], WD_DEC[task_idx],
                                                 enc_params, dec_params, OPTIM_DEC)
        for epoch in range(NUM_SEGM_EPOCHS[task_idx]):
            train_segmenter(segmenter, train_loader,
                            optim_enc, optim_dec,
                            epoch_start, segm_crit,
                            FREEZE_BN[task_idx])
            if (epoch + 1) % (VAL_EVERY[task_idx]) == 0:
                miou = validate(segmenter, val_loader, epoch_start, metricPath + "miousFreeze.txt", 2)
                # saver.save(
                #     miou,
                #     {'segmenter' : segmenter.state_dict(),
                #      'epoch_start' : epoch_start}, logger
                #      )
            epoch_start += 1
            
            torch.save(segmenter, modelPath + "modelFreeze_{}".format(epoch))

        logger.info("Stage {} finished, time spent {:.3f}min".format(
            task_idx, (time.time() - start) / 60.))
        
    # logger.info("All stages are now finished. Best Val is {:.3f}".format(
    #     saver.best_val))    

# if __name__ == '__main__':
#     logging.basicConfig(level=logging.INFO)
#     main()

# %% [markdown]
# ## Configurations and training

# %%
# DATASET PARAMETERS
TRAIN_DIR = "/content/drive/My Drive/DeepLearningX/TrainData-People/Train/"
VAL_DIR = "/content/drive/My Drive/DeepLearningX/TrainData-People/Validation/"
TRAIN_LIST = ["/content/drive/My Drive/DeepLearningX/TrainData-People/Train/train.txt"] * 3
VAL_LIST = ["/content/drive/My Drive/DeepLearningX/TrainData-People/Validation/validation.txt"] * 3
SHORTER_SIDE = [350] * 3
CROP_SIZE = [500] * 3
NORMALISE_PARAMS = [1./255, # SCALE
                    np.array([0.485, 0.456, 0.406]).reshape((1, 1, 3)), # MEAN
                    np.array([0.229, 0.224, 0.225]).reshape((1, 1, 3))] # STD
BATCH_SIZE = [10] * 3
NUM_WORKERS = 16
NUM_CLASSES = [21] * 3
LOW_SCALE = [0.5] * 3
HIGH_SCALE = [2.0] * 3
IGNORE_LABEL = 255

# ENCODER PARAMETERS
ENC = 'Mob' # Which model we are training
ENC_PRETRAINED = True  # pre-trained on ImageNet or randomly initialised

# GENERAL
EVALUATE = False
FREEZE_BN = [True] * 3
NUM_SEGM_EPOCHS = [50] * 3
PRINT_EVERY = 100
RANDOM_SEED = 42
SNAPSHOT_DIR = './ckpt/'
CKPT_PATH = './ckpt/checkpoint.pth.tar'
VAL_EVERY = [1] * 3 # how often to record validation scores

# OPTIMISERS' PARAMETERS
LR_ENC = [5e-4, 2.5e-4, 1e-4]  # TO FREEZE, PUT 0
LR_DEC = [5e-3, 2.5e-3, 1e-3]
MOM_ENC = [0.9] * 3 # TO FREEZE, PUT 0
MOM_DEC = [0.9] * 3
WD_ENC = [1e-5] * 3 # TO FREEZE, PUT 0
WD_DEC = [1e-5] * 3
OPTIM_DEC = 'sgd'

FreezeEnc = True
if FreezeEnc:
  LR_ENC = [0,0,0]
  MOM_ENC = [0,0,0]
  WD_ENC = [0,0,0]

# %%
metricPath = '/content/drive/My Drive/DeepLearningX/models/MobileNet/'
modelPath = "/content/drive/My Drive/DeepLearningX/models/MobileNet/"

main(modelPath, metricPath)
# Out:
# Downloading: "https://cloudstor.aarnet.edu.au/plus/s/PsEL9uEuxOtIxJV/download" to /root/.torch/models/rf_lwmbv2_voc.pth.tar
# INFO:__main__: Loaded Segmenter Mob, ImageNet-Pre-Trained=True, #PARAMS=3.28M
# INFO:__main__: Training Process Starts
# INFO:__main__: Created train set = 699 examples, val set = 100 examples
# INFO:__main__: Training Stage 0
# INFO:__main__: Train epoch: 0 [0/69]	Avg. Loss: 5.037	Avg. Time: 1.414
# INFO:__main__: IoUs: [0.88809033 0.61814472]
# INFO:__main__: Val epoch: 0	Mean IoU: 0.753
# INFO:__main__: Train epoch: 1 [0/69]	Avg. Loss: 0.085	Avg. Time: 1.360
# INFO:__main__: IoUs: [0.9135527 0.6893242]
# INFO:__main__: Val epoch: 1	Mean IoU: 0.801
# INFO:__main__: Train epoch: 2 [0/69]	Avg. Loss: 0.115	Avg. Time: 1.506
# INFO:__main__: IoUs: [0.91430991 0.69716163]
# INFO:__main__: Val epoch: 2	Mean IoU: 0.806
# INFO:__main__: Train epoch: 3 [0/69]	Avg. Loss: 0.097	Avg. Time: 1.583
# INFO:__main__: IoUs: [0.89589236 0.65417281]
# INFO:__main__: Val epoch: 3	Mean IoU: 0.775
# INFO:__main__: Train epoch: 4 [0/69]	Avg. Loss: 0.049	Avg. Time: 1.600
# INFO:__main__: IoUs: [0.89572579 0.64685441]
# INFO:__main__: Val epoch: 4	Mean IoU: 0.771
# INFO:__main__: Train epoch: 5 [0/69]	Avg. Loss: 0.072	Avg. Time: 1.508
# INFO:__main__: IoUs: [0.89708975 0.65444625]
# INFO:__main__: Val epoch: 5	Mean IoU: 0.776
# INFO:__main__: Train epoch: 6 [0/69]	Avg. Loss: 0.108	Avg. Time: 1.573
# INFO:__main__: IoUs: [0.89653584 0.66442437]
# INFO:__main__: Val epoch: 6	Mean IoU: 0.780
# INFO:__main__: Train epoch: 7 [0/69]	Avg. Loss: 0.072	Avg. Time: 1.527
# INFO:__main__: IoUs: [0.89720046 0.65174394]
# INFO:__main__: Val epoch: 7	Mean IoU: 0.774
# INFO:__main__: Train epoch: 8 [0/69]	Avg. Loss: 0.078	Avg. Time: 1.534
# INFO:__main__: IoUs: [0.89780289 0.65865054]
# INFO:__main__: Val epoch: 8	Mean IoU: 0.778
# INFO:__main__: Train epoch: 9 [0/69]	Avg. Loss: 0.063	Avg. Time: 1.487
# INFO:__main__: IoUs: [0.89712288 0.65979836]
# INFO:__main__: Val epoch: 9	Mean IoU: 0.778
# INFO:__main__: Train epoch: 10 [0/69]	Avg. Loss: 0.050	Avg. Time: 1.342
# INFO:__main__: IoUs: [0.89778217 0.65341405]
# INFO:__main__: Val epoch: 10	Mean IoU: 0.776
# INFO:__main__: Train epoch: 11 [0/69]	Avg. Loss: 0.052	Avg. Time: 1.528
# INFO:__main__: IoUs: [0.89745699 0.6540683 ]
# INFO:__main__: Val epoch: 11	Mean IoU: 0.776
# INFO:__main__: Train epoch: 12 [0/69]	Avg. Loss: 0.064	Avg. Time: 1.527
# INFO:__main__: IoUs: [0.89749737 0.66325448]
# INFO:__main__: Val epoch: 12	Mean IoU: 0.780
# INFO:__main__: Train epoch: 13 [0/69]	Avg. Loss: 0.051	Avg. Time: 1.471
# INFO:__main__: IoUs: [0.89858501 0.65867944]
# INFO:__main__: Val epoch: 13	Mean IoU: 0.779
# INFO:__main__: Train epoch: 14 [0/69]	Avg. Loss: 0.069	Avg. Time: 1.490
# INFO:__main__: IoUs: [0.89784517 0.66293883]
# INFO:__main__: Val epoch: 14	Mean IoU: 0.780
# INFO:__main__: Train epoch: 15 [0/69]	Avg. Loss: 0.092	Avg. Time: 1.634
# INFO:__main__: IoUs: [0.8982599 0.6548039]
# INFO:__main__: Val epoch: 15	Mean IoU: 0.777
# INFO:__main__: Train epoch: 16 [0/69]	Avg. Loss: 0.080	Avg. Time: 1.361
# INFO:__main__: IoUs: [0.89884171 0.65778025]
# INFO:__main__: Val epoch: 16	Mean IoU: 0.778
# INFO:__main__: Train epoch: 17 [0/69]	Avg. Loss: 0.108	Avg. Time: 1.592
# INFO:__main__: IoUs: [0.91955366 0.70752443]
# INFO:__main__: Val epoch: 17	Mean IoU: 0.814
# INFO:__main__: Train epoch: 18 [0/69]	Avg. Loss: 0.111	Avg. Time: 1.368
# INFO:__main__: IoUs: [0.89863837 0.65837447]
# INFO:__main__: Val epoch: 18	Mean IoU: 0.779
# INFO:__main__: Train epoch: 19 [0/69]	Avg. Loss: 0.066	Avg. Time: 1.541
# INFO:__main__: IoUs: [0.8983381  0.66419296]
# INFO:__main__: Val epoch: 19	Mean IoU: 0.781
# INFO:__main__: Train epoch: 20 [0/69]	Avg. Loss: 0.059	Avg. Time: 1.490
# INFO:__main__: IoUs: [0.89777047 0.65745187]
# INFO:__main__: Val epoch: 20	Mean IoU: 0.778
# INFO:__main__: Train epoch: 21 [0/69]	Avg. Loss: 0.039	Avg. Time: 1.601
# INFO:__main__: IoUs: [0.89694521 0.66363254]
# INFO:__main__: Val epoch: 21	Mean IoU: 0.780
# INFO:__main__: Train epoch: 22 [0/69]	Avg. Loss: 0.043	Avg. Time: 1.398
# INFO:__main__: IoUs: [0.89831108 0.66103044]
# INFO:__main__: Val epoch: 22	Mean IoU: 0.780
# INFO:__main__: Train epoch: 23 [0/69]	Avg. Loss: 0.033	Avg. Time: 1.618
# INFO:__main__: IoUs: [0.89838446 0.65696962]
# INFO:__main__: Val epoch: 23	Mean IoU: 0.778
# INFO:__main__: Train epoch: 24 [0/69]	Avg. Loss: 0.041	Avg. Time: 1.561
# INFO:__main__: IoUs: [0.9181448  0.70036301]
# INFO:__main__: Val epoch: 24	Mean IoU: 0.809
# INFO:__main__: Train epoch: 25 [0/69]	Avg. Loss: 0.082	Avg. Time: 1.504
# INFO:__main__: IoUs: [0.89957805 0.65985312]
# INFO:__main__: Val epoch: 25	Mean IoU: 0.780
# INFO:__main__: Train epoch: 26 [0/69]	Avg. Loss: 0.050	Avg. Time: 1.413
# INFO:__main__: IoUs: [0.89978567 0.66185808]
# INFO:__main__: Val epoch: 26	Mean IoU: 0.781
# INFO:__main__: Train epoch: 27 [0/69]	Avg. Loss: 0.058	Avg. Time: 1.431
# INFO:__main__: IoUs: [0.89730408 0.66258406]
# INFO:__main__: Val epoch: 27	Mean IoU: 0.780
# INFO:__main__: Train epoch: 28 [0/69]	Avg. Loss: 0.048	Avg. Time: 1.578
# INFO:__main__: IoUs: [0.91830087 0.70505509]
# INFO:__main__: Val epoch: 28	Mean IoU: 0.812
# INFO:__main__: Train epoch: 29 [0/69]	Avg. Loss: 0.045	Avg. Time: 1.641
# INFO:__main__: IoUs: [0.89868044 0.66214788]
# INFO:__main__: Val epoch: 29	Mean IoU: 0.780
# INFO:__main__: Train epoch: 30 [0/69]	Avg. Loss: 0.078	Avg. Time: 1.393
# INFO:__main__: IoUs: [0.89908577 0.66110232]
# INFO:__main__: Val epoch: 30	Mean IoU: 0.780
# INFO:__main__: Train epoch: 31 [0/69]	Avg. Loss: 0.061	Avg. Time: 1.545
# INFO:__main__: IoUs: [0.91906757 0.70674454]
# INFO:__main__: Val epoch: 31	Mean IoU: 0.813
# INFO:__main__: Train epoch: 32 [0/69]	Avg. Loss: 0.055	Avg. Time: 1.516
# INFO:__main__: IoUs: [0.89778012 0.66022068]
# INFO:__main__: Val epoch: 32	Mean IoU: 0.779
# INFO:__main__: Train epoch: 33 [0/69]	Avg. Loss: 0.030	Avg. Time: 1.558
# INFO:__main__: IoUs: [0.89880788 0.66315136]
# INFO:__main__: Val epoch: 33	Mean IoU: 0.781
# INFO:__main__: Train epoch: 34 [0/69]	Avg. Loss: 0.047	Avg. Time: 1.571
# INFO:__main__: IoUs: [0.89787994 0.66189528]
# INFO:__main__: Val epoch: 34	Mean IoU: 0.780
# INFO:__main__: Train epoch: 35 [0/69]	Avg. Loss: 0.034	Avg. Time: 1.549
# INFO:__main__: IoUs: [0.91962141 0.70556449]
# INFO:__main__: Val epoch: 35	Mean IoU: 0.813
# INFO:__main__: Train epoch: 36 [0/69]	Avg. Loss: 0.066	Avg. Time: 1.407
# INFO:__main__: IoUs: [0.91936971 0.70603231]
# INFO:__main__: Val epoch: 36	Mean IoU: 0.813
# INFO:__main__: Train epoch: 37 [0/69]	Avg. Loss: 0.060	Avg. Time: 1.589
# INFO:__main__: IoUs: [0.91912819 0.70568347]
# INFO:__main__: Val epoch: 37	Mean IoU: 0.812
# INFO:__main__: Train epoch: 38 [0/69]	Avg. Loss: 0.054	Avg. Time: 1.604
# INFO:__main__: IoUs: [0.91607474 0.70233123]
# INFO:__main__: Val epoch: 38	Mean IoU: 0.809
# INFO:__main__: Train epoch: 39 [0/69]	Avg. Loss: 0.119	Avg. Time: 1.581
# INFO:__main__: IoUs: [0.89857737 0.66061689]
# INFO:__main__: Val epoch: 39	Mean IoU: 0.780
# INFO:__main__: Train epoch: 40 [0/69]	Avg. Loss: 0.061	Avg. Time: 1.523
# INFO:__main__: IoUs: [0.89819496 0.66335306]
# INFO:__main__: Val epoch: 40	Mean IoU: 0.781
# INFO:__main__: Train epoch: 41 [0/69]	Avg. Loss: 0.062	Avg. Time: 1.577
# INFO:__main__: IoUs: [0.89855038 0.66090892]
# INFO:__main__: Val epoch: 41	Mean IoU: 0.780
# INFO:__main__: Train epoch: 42 [0/69]	Avg. Loss: 0.039	Avg. Time: 1.629
# INFO:__main__: IoUs: [0.89861738 0.66061002]
# INFO:__main__: Val epoch: 42	Mean IoU: 0.780
# INFO:__main__: Train epoch: 43 [0/69]	Avg. Loss: 0.052	Avg. Time: 1.390
# INFO:__main__: IoUs: [0.89716864 0.66146288]
# INFO:__main__: Val epoch: 43	Mean IoU: 0.779
# INFO:__main__: Train epoch: 44 [0/69]	Avg. Loss: 0.062	Avg. Time: 1.453
# INFO:__main__: IoUs: [0.91801647 0.70202061]
# INFO:__main__: Val epoch: 44	Mean IoU: 0.810
# INFO:__main__: Train epoch: 45 [0/69]	Avg. Loss: 0.075	Avg. Time: 1.474
# INFO:__main__: IoUs: [0.91834408 0.70429049]
# INFO:__main__: Val epoch: 45	Mean IoU: 0.811
# INFO:__main__: Train epoch: 46 [0/69]	Avg. Loss: 0.064	Avg. Time: 1.454
# INFO:__main__: IoUs: [0.8978187  0.66177513]
# INFO:__main__: Val epoch: 46	Mean IoU: 0.780
# INFO:__main__: Train epoch: 47 [0/69]	Avg. Loss: 0.084	Avg. Time: 1.517
# INFO:__main__: IoUs: [0.8979818  0.65850664]
# INFO:__main__: Val epoch: 47	Mean IoU: 0.778
# INFO:__main__: Train epoch: 48 [0/69]	Avg. Loss: 0.046	Avg. Time: 1.538
# INFO:__main__: IoUs: [0.89843483 0.65795447]
# INFO:__main__: Val epoch: 48	Mean IoU: 0.778
# INFO:__main__: Train epoch: 49 [0/69]	Avg. Loss: 0.026	Avg. Time: 1.501
# INFO:__main__: IoUs: [0.89885243 0.66339157]
# INFO:__main__: Val epoch: 49	Mean IoU: 0.781
# INFO:__main__:Stage 0 finished, time spent 94.294min
# INFO:__main__: Created train set = 699 examples, val set = 100 examples
# INFO:__main__: Training Stage 1
# INFO:__main__: Train epoch: 50 [0/69]	Avg. Loss: 0.035	Avg. Time: 1.797
# INFO:__main__: IoUs: [0.91872125 0.7059214 ]
# INFO:__main__: Val epoch: 50	Mean IoU: 0.812
# INFO:__main__: Train epoch: 51 [0/69]	Avg. Loss: 0.060	Avg. Time: 1.361
# INFO:__main__: IoUs: [0.89834366 0.66319089]
# INFO:__main__: Val epoch: 51	Mean IoU: 0.781
# INFO:__main__: Train epoch: 52 [0/69]	Avg. Loss: 0.039	Avg. Time: 1.593
# INFO:__main__: IoUs: [0.91784049 0.70525476]
# INFO:__main__: Val epoch: 52	Mean IoU: 0.812
# INFO:__main__: Train epoch: 53 [0/69]	Avg. Loss: 0.046	Avg. Time: 1.497
# INFO:__main__: IoUs: [0.89762749 0.66295066]
# INFO:__main__: Val epoch: 53	Mean IoU: 0.780
# INFO:__main__: Train epoch: 54 [0/69]	Avg. Loss: 0.043	Avg. Time: 1.541
# INFO:__main__: IoUs: [0.89779647 0.66256836]
# INFO:__main__: Val epoch: 54	Mean IoU: 0.780
# INFO:__main__: Train epoch: 55 [0/69]	Avg. Loss: 0.050	Avg. Time: 1.557
# INFO:__main__: IoUs: [0.89844159 0.66332621]
# INFO:__main__: Val epoch: 55	Mean IoU: 0.781
# INFO:__main__: Train epoch: 56 [0/69]	Avg. Loss: 0.049	Avg. Time: 1.551
# INFO:__main__: IoUs: [0.89884525 0.66287146]
# INFO:__main__: Val epoch: 56	Mean IoU: 0.781
# INFO:__main__: Train epoch: 57 [0/69]	Avg. Loss: 0.027	Avg. Time: 1.584
# INFO:__main__: IoUs: [0.89807332 0.66316944]
# INFO:__main__: Val epoch: 57	Mean IoU: 0.781
# INFO:__main__: Train epoch: 58 [0/69]	Avg. Loss: 0.083	Avg. Time: 1.396
# INFO:__main__: IoUs: [0.89846491 0.66340118]
# INFO:__main__: Val epoch: 58	Mean IoU: 0.781
# INFO:__main__: Train epoch: 59 [0/69]	Avg. Loss: 0.042	Avg. Time: 1.497
# INFO:__main__: IoUs: [0.91948332 0.70586031]
# INFO:__main__: Val epoch: 59	Mean IoU: 0.813
# INFO:__main__: Train epoch: 60 [0/69]	Avg. Loss: 0.059	Avg. Time: 1.548
# INFO:__main__: IoUs: [0.91916348 0.70422877]
# INFO:__main__: Val epoch: 60	Mean IoU: 0.812
# INFO:__main__: Train epoch: 61 [0/69]	Avg. Loss: 0.053	Avg. Time: 1.665
# INFO:__main__: IoUs: [0.91901008 0.70090092]
# INFO:__main__: Val epoch: 61	Mean IoU: 0.810
# INFO:__main__: Train epoch: 62 [0/69]	Avg. Loss: 0.051	Avg. Time: 1.463
# INFO:__main__: IoUs: [0.91910379 0.70525235]
# INFO:__main__: Val epoch: 62	Mean IoU: 0.812
# INFO:__main__: Train epoch: 63 [0/69]	Avg. Loss: 0.054	Avg. Time: 1.577
# INFO:__main__: IoUs: [0.91724086 0.702546  ]
# INFO:__main__: Val epoch: 63	Mean IoU: 0.810
# INFO:__main__: Train epoch: 64 [0/69]	Avg. Loss: 0.041	Avg. Time: 1.538
# INFO:__main__: IoUs: [0.89886843 0.65861199]
# INFO:__main__: Val epoch: 64	Mean IoU: 0.779
# INFO:__main__: Train epoch: 65 [0/69]	Avg. Loss: 0.037	Avg. Time: 1.455
# INFO:__main__: IoUs: [0.9195441  0.70485403]
# INFO:__main__: Val epoch: 65	Mean IoU: 0.812
# INFO:__main__: Train epoch: 66 [0/69]	Avg. Loss: 0.056	Avg. Time: 1.447
# INFO:__main__: IoUs: [0.89830481 0.66143855]
# INFO:__main__: Val epoch: 66	Mean IoU: 0.780
# INFO:__main__: Train epoch: 67 [0/69]	Avg. Loss: 0.027	Avg. Time: 1.587
# INFO:__main__: IoUs: [0.91859508 0.70321259]
# INFO:__main__: Val epoch: 67	Mean IoU: 0.811
# INFO:__main__: Train epoch: 68 [0/69]	Avg. Loss: 0.039	Avg. Time: 1.531
# INFO:__main__: IoUs: [0.91937085 0.70345244]
# INFO:__main__: Val epoch: 68	Mean IoU: 0.811
# INFO:__main__: Train epoch: 69 [0/69]	Avg. Loss: 0.039	Avg. Time: 1.372
# INFO:__main__: IoUs: [0.91698652 0.70175019]
# INFO:__main__: Val epoch: 69	Mean IoU: 0.809
# INFO:__main__: Train epoch: 70 [0/69]	Avg. Loss: 0.049	Avg. Time: 1.500
# INFO:__main__: IoUs: [0.91943109 0.70212042]
# INFO:__main__: Val epoch: 70	Mean IoU: 0.811
# INFO:__main__: Train epoch: 71 [0/69]	Avg. Loss: 0.021	Avg. Time: 1.548
# INFO:__main__: IoUs: [0.89856523 0.660875  ]
# INFO:__main__: Val epoch: 71	Mean IoU: 0.780
# INFO:__main__: Train epoch: 72 [0/69]	Avg. Loss: 0.036	Avg. Time: 1.488
# INFO:__main__: IoUs: [0.89802942 0.66028622]
# INFO:__main__: Val epoch: 72	Mean IoU: 0.779
# INFO:__main__: Train epoch: 73 [0/69]	Avg. Loss: 0.034	Avg. Time: 1.480
# INFO:__main__: IoUs: [0.8985869  0.66079354]
# INFO:__main__: Val epoch: 73	Mean IoU: 0.780
# INFO:__main__: Train epoch: 74 [0/69]	Avg. Loss: 0.051	Avg. Time: 1.403
# INFO:__main__: IoUs: [0.9186473  0.70309315]
# INFO:__main__: Val epoch: 74	Mean IoU: 0.811
# INFO:__main__: Train epoch: 75 [0/69]	Avg. Loss: 0.044	Avg. Time: 1.482
# INFO:__main__: IoUs: [0.91962397 0.70547482]
# INFO:__main__: Val epoch: 75	Mean IoU: 0.813
# INFO:__main__: Train epoch: 76 [0/69]	Avg. Loss: 0.035	Avg. Time: 1.531
# INFO:__main__: IoUs: [0.91820195 0.70359552]
# INFO:__main__: Val epoch: 76	Mean IoU: 0.811
# INFO:__main__: Train epoch: 77 [0/69]	Avg. Loss: 0.045	Avg. Time: 1.542
# INFO:__main__: IoUs: [0.89768938 0.65998141]
# INFO:__main__: Val epoch: 77	Mean IoU: 0.779
# INFO:__main__: Train epoch: 78 [0/69]	Avg. Loss: 0.046	Avg. Time: 1.683
# INFO:__main__: IoUs: [0.89777748 0.66068881]
# INFO:__main__: Val epoch: 78	Mean IoU: 0.779
# INFO:__main__: Train epoch: 79 [0/69]	Avg. Loss: 0.038	Avg. Time: 1.673
# INFO:__main__: IoUs: [0.89741286 0.66131357]
# INFO:__main__: Val epoch: 79	Mean IoU: 0.779
# INFO:__main__: Train epoch: 80 [0/69]	Avg. Loss: 0.036	Avg. Time: 1.535
# INFO:__main__: IoUs: [0.89626442 0.66040504]
# INFO:__main__: Val epoch: 80	Mean IoU: 0.778
# INFO:__main__: Train epoch: 81 [0/69]	Avg. Loss: 0.070	Avg. Time: 1.376
# INFO:__main__: IoUs: [0.91856191 0.70147845]
# INFO:__main__: Val epoch: 81	Mean IoU: 0.810
# INFO:__main__: Train epoch: 82 [0/69]	Avg. Loss: 0.047	Avg. Time: 1.389
# INFO:__main__: IoUs: [0.89835544 0.66104617]
# INFO:__main__: Val epoch: 82	Mean IoU: 0.780
# INFO:__main__: Train epoch: 83 [0/69]	Avg. Loss: 0.064	Avg. Time: 1.475
# INFO:__main__: IoUs: [0.89800497 0.6624905 ]
# INFO:__main__: Val epoch: 83	Mean IoU: 0.780
# INFO:__main__: Train epoch: 84 [0/69]	Avg. Loss: 0.039	Avg. Time: 1.509
# INFO:__main__: IoUs: [0.89861306 0.65855712]
# INFO:__main__: Val epoch: 84	Mean IoU: 0.779
# INFO:__main__: Train epoch: 85 [0/69]	Avg. Loss: 0.067	Avg. Time: 1.532
# INFO:__main__: IoUs: [0.89744058 0.66128786]
# INFO:__main__: Val epoch: 85	Mean IoU: 0.779
# INFO:__main__: Train epoch: 86 [0/69]	Avg. Loss: 0.072	Avg. Time: 1.505
# INFO:__main__: IoUs: [0.8976401  0.65995415]
# INFO:__main__: Val epoch: 86	Mean IoU: 0.779
# INFO:__main__: Train epoch: 87 [0/69]	Avg. Loss: 0.089	Avg. Time: 1.530
# INFO:__main__: IoUs: [0.8973001  0.66068413]
# INFO:__main__: Val epoch: 87	Mean IoU: 0.779
# INFO:__main__: Train epoch: 88 [0/69]	Avg. Loss: 0.058	Avg. Time: 1.635
# INFO:__main__: IoUs: [0.89649316 0.65989214]
# INFO:__main__: Val epoch: 88	Mean IoU: 0.778
# INFO:__main__: Train epoch: 89 [0/69]	Avg. Loss: 0.054	Avg. Time: 1.535
# INFO:__main__: IoUs: [0.91705512 0.70030827]
# INFO:__main__: Val epoch: 89	Mean IoU: 0.809
# INFO:__main__: Train epoch: 90 [0/69]	Avg. Loss: 0.071	Avg. Time: 1.572
# INFO:__main__: IoUs: [0.89760864 0.65827409]
# INFO:__main__: Val epoch: 90	Mean IoU: 0.778
# INFO:__main__: Train epoch: 91 [0/69]	Avg. Loss: 0.065	Avg. Time: 1.562
# INFO:__main__: IoUs: [0.89731684 0.65870527]
# INFO:__main__: Val epoch: 91	Mean IoU: 0.778
# INFO:__main__: Train epoch: 92 [0/69]	Avg. Loss: 0.050	Avg. Time: 1.452
# INFO:__main__: IoUs: [0.89720838 0.65928309]
# INFO:__main__: Val epoch: 92	Mean IoU: 0.778
# INFO:__main__: Train epoch: 93 [0/69]	Avg. Loss: 0.055	Avg. Time: 1.585
# INFO:__main__: IoUs: [0.89729564 0.65950822]
# INFO:__main__: Val epoch: 93	Mean IoU: 0.778
# INFO:__main__: Train epoch: 94 [0/69]	Avg. Loss: 0.089	Avg. Time: 1.575
# INFO:__main__: IoUs: [0.89731168 0.6605062 ]
# INFO:__main__: Val epoch: 94	Mean IoU: 0.779
# INFO:__main__: Train epoch: 95 [0/69]	Avg. Loss: 0.027	Avg. Time: 1.437
# INFO:__main__: IoUs: [0.89795897 0.65932147]
# INFO:__main__: Val epoch: 95	Mean IoU: 0.779
# INFO:__main__: Train epoch: 96 [0/69]	Avg. Loss: 0.037	Avg. Time: 1.489
# INFO:__main__: IoUs: [0.91921671 0.70276462]
# INFO:__main__: Val epoch: 96	Mean IoU: 0.811
# INFO:__main__: Train epoch: 97 [0/69]	Avg. Loss: 0.055	Avg. Time: 1.391
# INFO:__main__: IoUs: [0.91846725 0.70216491]
# INFO:__main__: Val epoch: 97	Mean IoU: 0.810
# INFO:__main__: Train epoch: 98 [0/69]	Avg. Loss: 0.041	Avg. Time: 1.573
# INFO:__main__: IoUs: [0.91858766 0.70165894]
# INFO:__main__: Val epoch: 98	Mean IoU: 0.810
# INFO:__main__: Train epoch: 99 [0/69]	Avg. Loss: 0.045	Avg. Time: 1.521
# INFO:__main__: IoUs: [0.9187826  0.70206149]
# INFO:__main__: Val epoch: 99	Mean IoU: 0.810
# INFO:__main__:Stage 1 finished, time spent 94.357min
# INFO:__main__: Created train set = 699 examples, val set = 100 examples
# INFO:__main__: Training Stage 2
# INFO:__main__: Train epoch: 100 [0/69]	Avg. Loss: 0.035	Avg. Time: 1.923
# INFO:__main__: IoUs: [0.91868227 0.7021011 ]
# INFO:__main__: Val epoch: 100	Mean IoU: 0.810
# INFO:__main__: Train epoch: 101 [0/69]	Avg. Loss: 0.031	Avg. Time: 1.565
# INFO:__main__: IoUs: [0.898026   0.66103632]
# INFO:__main__: Val epoch: 101	Mean IoU: 0.780
# INFO:__main__: Train epoch: 102 [0/69]	Avg. Loss: 0.051	Avg. Time: 1.371
# INFO:__main__: IoUs: [0.91841127 0.70238083]
# INFO:__main__: Val epoch: 102	Mean IoU: 0.810
# INFO:__main__: Train epoch: 103 [0/69]	Avg. Loss: 0.048	Avg. Time: 1.466
# INFO:__main__: IoUs: [0.91870557 0.70179905]
# INFO:__main__: Val epoch: 103	Mean IoU: 0.810
# INFO:__main__: Train epoch: 104 [0/69]	Avg. Loss: 0.055	Avg. Time: 1.595
# INFO:__main__: IoUs: [0.91872712 0.70196074]
# INFO:__main__: Val epoch: 104	Mean IoU: 0.810
# INFO:__main__: Train epoch: 105 [0/69]	Avg. Loss: 0.067	Avg. Time: 1.449
# INFO:__main__: IoUs: [0.91855943 0.70243986]
# INFO:__main__: Val epoch: 105	Mean IoU: 0.810
# INFO:__main__: Train epoch: 106 [0/69]	Avg. Loss: 0.033	Avg. Time: 1.586
# INFO:__main__: IoUs: [0.91905737 0.70146702]
# INFO:__main__: Val epoch: 106	Mean IoU: 0.810
# INFO:__main__: Train epoch: 107 [0/69]	Avg. Loss: 0.030	Avg. Time: 1.436
# INFO:__main__: IoUs: [0.91762793 0.70156345]
# INFO:__main__: Val epoch: 107	Mean IoU: 0.810
# INFO:__main__: Train epoch: 108 [0/69]	Avg. Loss: 0.070	Avg. Time: 1.338
# INFO:__main__: IoUs: [0.91884684 0.70321162]
# INFO:__main__: Val epoch: 108	Mean IoU: 0.811
# INFO:__main__: Train epoch: 109 [0/69]	Avg. Loss: 0.039	Avg. Time: 1.520
# INFO:__main__: IoUs: [0.91889536 0.70197747]
# INFO:__main__: Val epoch: 109	Mean IoU: 0.810
# INFO:__main__: Train epoch: 110 [0/69]	Avg. Loss: 0.065	Avg. Time: 1.369
# INFO:__main__: IoUs: [0.89807997 0.66010565]
# INFO:__main__: Val epoch: 110	Mean IoU: 0.779
# INFO:__main__: Train epoch: 111 [0/69]	Avg. Loss: 0.047	Avg. Time: 1.697
# INFO:__main__: IoUs: [0.91896569 0.70242947]
# INFO:__main__: Val epoch: 111	Mean IoU: 0.811
# INFO:__main__: Train epoch: 112 [0/69]	Avg. Loss: 0.043	Avg. Time: 1.631
# INFO:__main__: IoUs: [0.9189922  0.70286014]
# INFO:__main__: Val epoch: 112	Mean IoU: 0.811
# INFO:__main__: Train epoch: 113 [0/69]	Avg. Loss: 0.061	Avg. Time: 1.448
# INFO:__main__: IoUs: [0.91901048 0.70463586]
# INFO:__main__: Val epoch: 113	Mean IoU: 0.812
# INFO:__main__: Train epoch: 114 [0/69]	Avg. Loss: 0.051	Avg. Time: 1.766
# INFO:__main__: IoUs: [0.89821793 0.66024371]
# INFO:__main__: Val epoch: 114	Mean IoU: 0.779
# INFO:__main__: Train epoch: 115 [0/69]	Avg. Loss: 0.059	Avg. Time: 1.549
# INFO:__main__: IoUs: [0.89791662 0.65999734]
# INFO:__main__: Val epoch: 115	Mean IoU: 0.779
# INFO:__main__: Train epoch: 116 [0/69]	Avg. Loss: 0.047	Avg. Time: 1.580
# INFO:__main__: IoUs: [0.89795469 0.66010556]
# INFO:__main__: Val epoch: 116	Mean IoU: 0.779
# INFO:__main__: Train epoch: 117 [0/69]	Avg. Loss: 0.044	Avg. Time: 1.657
# INFO:__main__: IoUs: [0.91830371 0.70184206]
# INFO:__main__: Val epoch: 117	Mean IoU: 0.810
# INFO:__main__: Train epoch: 118 [0/69]	Avg. Loss: 0.057	Avg. Time: 1.537
# INFO:__main__: IoUs: [0.89809545 0.6606907 ]
# INFO:__main__: Val epoch: 118	Mean IoU: 0.779
# INFO:__main__: Train epoch: 119 [0/69]	Avg. Loss: 0.114	Avg. Time: 1.598
# INFO:__main__: IoUs: [0.91893841 0.70370483]
# INFO:__main__: Val epoch: 119	Mean IoU: 0.811
# INFO:__main__: Train epoch: 120 [0/69]	Avg. Loss: 0.033	Avg. Time: 1.615
# INFO:__main__: IoUs: [0.91918384 0.70197117]
# INFO:__main__: Val epoch: 120	Mean IoU: 0.811
# INFO:__main__: Train epoch: 121 [0/69]	Avg. Loss: 0.037	Avg. Time: 1.695
# INFO:__main__: IoUs: [0.91886076 0.70277842]
# INFO:__main__: Val epoch: 121	Mean IoU: 0.811
# INFO:__main__: Train epoch: 122 [0/69]	Avg. Loss: 0.028	Avg. Time: 1.411
# INFO:__main__: IoUs: [0.91827886 0.70280366]
# INFO:__main__: Val epoch: 122	Mean IoU: 0.811
# INFO:__main__: Train epoch: 123 [0/69]	Avg. Loss: 0.044	Avg. Time: 1.609
# INFO:__main__: IoUs: [0.91894399 0.70368933]
# INFO:__main__: Val epoch: 123	Mean IoU: 0.811
# INFO:__main__: Train epoch: 124 [0/69]	Avg. Loss: 0.073	Avg. Time: 1.432
# INFO:__main__: IoUs: [0.89786684 0.65860049]
# INFO:__main__: Val epoch: 124	Mean IoU: 0.778
# INFO:__main__: Train epoch: 125 [0/69]	Avg. Loss: 0.059	Avg. Time: 1.375
# INFO:__main__: IoUs: [0.89790337 0.65907596]
# INFO:__main__: Val epoch: 125	Mean IoU: 0.778
# INFO:__main__: Train epoch: 126 [0/69]	Avg. Loss: 0.056	Avg. Time: 1.682
# INFO:__main__: IoUs: [0.91866747 0.70355176]
# INFO:__main__: Val epoch: 126	Mean IoU: 0.811
# INFO:__main__: Train epoch: 127 [0/69]	Avg. Loss: 0.045	Avg. Time: 1.477
# INFO:__main__: IoUs: [0.91873569 0.70151407]
# INFO:__main__: Val epoch: 127	Mean IoU: 0.810
# INFO:__main__: Train epoch: 128 [0/69]	Avg. Loss: 0.029	Avg. Time: 1.504
# INFO:__main__: IoUs: [0.91855383 0.7008456 ]
# INFO:__main__: Val epoch: 128	Mean IoU: 0.810
# INFO:__main__: Train epoch: 129 [0/69]	Avg. Loss: 0.063	Avg. Time: 1.497
# INFO:__main__: IoUs: [0.91800337 0.70164847]
# INFO:__main__: Val epoch: 129	Mean IoU: 0.810
# INFO:__main__: Train epoch: 130 [0/69]	Avg. Loss: 0.054	Avg. Time: 1.575
# INFO:__main__: IoUs: [0.91823494 0.70045249]
# INFO:__main__: Val epoch: 130	Mean IoU: 0.809
# INFO:__main__: Train epoch: 131 [0/69]	Avg. Loss: 0.045	Avg. Time: 1.416
# INFO:__main__: IoUs: [0.91877167 0.70238236]
# INFO:__main__: Val epoch: 131	Mean IoU: 0.811
# INFO:__main__: Train epoch: 132 [0/69]	Avg. Loss: 0.025	Avg. Time: 1.646
# INFO:__main__: IoUs: [0.91836104 0.70052674]
# INFO:__main__: Val epoch: 132	Mean IoU: 0.809
# INFO:__main__: Train epoch: 133 [0/69]	Avg. Loss: 0.033	Avg. Time: 1.387
# INFO:__main__: IoUs: [0.91805422 0.70207668]
# INFO:__main__: Val epoch: 133	Mean IoU: 0.810
# INFO:__main__: Train epoch: 134 [0/69]	Avg. Loss: 0.050	Avg. Time: 1.442
# INFO:__main__: IoUs: [0.91875603 0.70262514]
# INFO:__main__: Val epoch: 134	Mean IoU: 0.811
# INFO:__main__: Train epoch: 135 [0/69]	Avg. Loss: 0.054	Avg. Time: 1.572
# INFO:__main__: IoUs: [0.91824042 0.70202525]
# INFO:__main__: Val epoch: 135	Mean IoU: 0.810
# INFO:__main__: Train epoch: 136 [0/69]	Avg. Loss: 0.046	Avg. Time: 1.358
# INFO:__main__: IoUs: [0.8974152  0.65970025]
# INFO:__main__: Val epoch: 136	Mean IoU: 0.779
# INFO:__main__: Train epoch: 137 [0/69]	Avg. Loss: 0.033	Avg. Time: 1.500
# INFO:__main__: IoUs: [0.91785402 0.70159865]
# INFO:__main__: Val epoch: 137	Mean IoU: 0.810
# INFO:__main__: Train epoch: 138 [0/69]	Avg. Loss: 0.030	Avg. Time: 1.538
# INFO:__main__: IoUs: [0.89691394 0.6582995 ]
# INFO:__main__: Val epoch: 138	Mean IoU: 0.778
# INFO:__main__: Train epoch: 139 [0/69]	Avg. Loss: 0.048	Avg. Time: 1.523
# INFO:__main__: IoUs: [0.89794478 0.65843042]
# INFO:__main__: Val epoch: 139	Mean IoU: 0.778
# INFO:__main__: Train epoch: 140 [0/69]	Avg. Loss: 0.046	Avg. Time: 1.412
# INFO:__main__: IoUs: [0.89784365 0.66023184]
# INFO:__main__: Val epoch: 140	Mean IoU: 0.779
# INFO:__main__: Train epoch: 141 [0/69]	Avg. Loss: 0.149	Avg. Time: 1.466
# INFO:__main__: IoUs: [0.91859497 0.7023521 ]
# INFO:__main__: Val epoch: 141	Mean IoU: 0.810
# INFO:__main__: Train epoch: 142 [0/69]	Avg. Loss: 0.033	Avg. Time: 1.562
# INFO:__main__: IoUs: [0.89754143 0.66000191]
# INFO:__main__: Val epoch: 142	Mean IoU: 0.779
# INFO:__main__: Train epoch: 143 [0/69]	Avg. Loss: 0.049	Avg. Time: 1.463
# INFO:__main__: IoUs: [0.89684561 0.65903762]
# INFO:__main__: Val epoch: 143	Mean IoU: 0.778
# INFO:__main__: Train epoch: 144 [0/69]	Avg. Loss: 0.064	Avg. Time: 1.604
# INFO:__main__: IoUs: [0.89705714 0.66052578]
# INFO:__main__: Val epoch: 144	Mean IoU: 0.779
# INFO:__main__: Train epoch: 145 [0/69]	Avg. Loss: 0.054	Avg. Time: 1.597
# INFO:__main__: IoUs: [0.8965215  0.65573153]
# INFO:__main__: Val epoch: 145	Mean IoU: 0.776
# INFO:__main__: Train epoch: 146 [0/69]	Avg. Loss: 0.037	Avg. Time: 1.518
# INFO:__main__: IoUs: [0.91841197 0.70150106]
# INFO:__main__: Val epoch: 146	Mean IoU: 0.810
# INFO:__main__: Train epoch: 147 [0/69]	Avg. Loss: 0.051	Avg. Time: 1.445
# INFO:__main__: IoUs: [0.89730315 0.65899741]
# INFO:__main__: Val epoch: 147	Mean IoU: 0.778
# INFO:__main__: Train epoch: 148 [0/69]	Avg. Loss: 0.041	Avg. Time: 1.393
# INFO:__main__: IoUs: [0.91811201 0.7027784 ]
# INFO:__main__: Val epoch: 148	Mean IoU: 0.810
# INFO:__main__: Train epoch: 149 [0/69]	Avg. Loss: 0.078	Avg. Time: 1.488
# INFO:__main__: IoUs: [0.89699792 0.65957975]
# INFO:__main__: Val epoch: 149	Mean IoU: 0.778
# INFO:__main__:Stage 2 finished, time spent 94.337min
